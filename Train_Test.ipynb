# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split, learning_curve
# %matplotlib inline

# %%
X = np.random.rand(200) * 20
Y = 0.2 * X**4 - 1.3 * X**3 + 0.52 * X**2 + 3 * X + 5
Y = Y + np.random.normal(scale = 2000, size = Y.shape)
X = X.reshape(-1, 1)
Y = Y.reshape(-1, 1)
plt.plot(X,Y, 'bo')
MSE = []
MSET = []

# %%
split = int(X.shape[0] * 0.8)
X_train = X[:split]
Y_train = Y[:split]
X_test = X[split:]
Y_test = Y[split:]

# %%
model = LinearRegression(normalize = True)

# %%
poly1 = PolynomialFeatures(degree = 1)
X1 = poly1.fit_transform(X_train)
X1_t = poly1.fit_transform(X_test)
model.fit(X1,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
X1_plot = np.arange(-10,20,0.1).reshape(-1,1)
X1_plot_poly = poly1.fit_transform(X1_plot)
plt.scatter(X_train, Y_train, color = "blue")
plt.scatter(X_test, Y_test, color = "cyan")
plt.plot(X1_plot[:,0],model.predict(X1_plot_poly),'r--')

# %%
h1 = model.predict(X1)
MSE.append(np.mean((Y_train - h1) ** 2)/2)

# %%
ht1 = model.predict(X1_t)
MSET.append(np.mean((Y_test - ht1) ** 2)/2)

# %%
print('train score:', model.score(X1, Y_train))
print('test score:', model.score(X1_t, Y_test))
# Out:
# train score: 0.5998599562266578
# test score: 0.7287650143033273

# %%
poly2 = PolynomialFeatures(degree = 2)
X2 = poly2.fit_transform(X_train)
X2_t = poly2.fit_transform(X_test)
model.fit(X2,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
X2_plot = np.arange(-10,20,0.1).reshape(-1,1)
X2_plot_poly = poly2.fit_transform(X2_plot)
plt.scatter(X_train, Y_train, color = "blue")
plt.scatter(X_test, Y_test, color = "cyan")
plt.plot(X2_plot[:,0],model.predict(X2_plot_poly),'r--')

# %%
h2 = model.predict(X2)
MSE.append(np.mean((Y_train - h2) ** 2)/2)

# %%
ht2 = model.predict(X2_t)
MSET.append(np.mean((Y_test - ht2) ** 2)/2)

# %%
print('train score:', model.score(X2, Y_train))
print('test score:', model.score(X2_t, Y_test))
# Out:
# train score: 0.8471756341322532
# test score: 0.9226191646016715

# %%
poly4 = PolynomialFeatures(degree = 4)
X4 = poly4.fit_transform(X_train)
X4_t = poly4.fit_transform(X_test)
model.fit(X4,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
X4_plot = np.arange(-10,20,0.1).reshape(-1,1)
X4_plot_poly = poly4.fit_transform(X4_plot)
plt.scatter(X_train, Y_train, color = "blue")
plt.scatter(X_test, Y_test, color = "cyan")
plt.plot(X4_plot[:,0],model.predict(X4_plot_poly),'r--')

# %%
h4 = model.predict(X4)
MSE.append(np.mean((Y_train - h4) ** 2)/2)

# %%
ht4 = model.predict(X4_t)
MSET.append(np.mean((Y_test - ht4) ** 2)/2)

# %%
print('train score:', model.score(X4, Y_train))
print('test score:', model.score(X4_t, Y_test))
# Out:
# train score: 0.8875078197295208
# test score: 0.904778441473549

# %%
poly8 = PolynomialFeatures(degree = 8)
X8 = poly8.fit_transform(X_train)
X8_t = poly8.fit_transform(X_test)
model.fit(X8,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
X8_plot = np.arange(-10,20,0.1).reshape(-1,1)
X8_plot_poly = poly8.fit_transform(X8_plot)
plt.scatter(X_train, Y_train, color = "blue")
plt.scatter(X_test, Y_test, color = "cyan")
plt.plot(X8_plot[:,0],model.predict(X8_plot_poly),'r--')

# %%
h8 = model.predict(X8)
MSE.append(np.mean((Y_train - h8) ** 2)/2)

# %%
ht8 = model.predict(X8_t)
MSET.append(np.mean((Y_test - ht8) ** 2)/2)

# %%
print('train score:', model.score(X8, Y_train))
print('test score:', model.score(X8_t, Y_test))
# Out:
# train score: 0.8888038401825666
# test score: 0.9134196682689399

# %%
poly16 = PolynomialFeatures(degree = 16)
X16 = poly16.fit_transform(X_train)
X16_t = poly16.fit_transform(X_test)
model.fit(X16,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
X16_plot = np.arange(-10,20,0.1).reshape(-1,1)
X16_plot_poly = poly16.fit_transform(X16_plot)
plt.scatter(X_train, Y_train, color = "blue")
plt.scatter(X_test, Y_test, color = "cyan")
plt.plot(X16_plot[:,0],model.predict(X16_plot_poly),'r--')

# %%
h16 = model.predict(X16)
MSE.append(np.mean((Y_train - h16) ** 2)/2)

# %%
ht16 = model.predict(X16_t)
MSET.append(np.mean((Y_test - ht16) ** 2)/2)

# %%
print('train score:', model.score(X16, Y_train))
print('test score:', model.score(X16_t, Y_test))
# Out:
# train score: 0.8933513804869753
# test score: 0.9109656423372332

# %%
power = [1,2,4,8,16]
power = np.array(power)

# %%
plt.plot(MSE,power,'g*')
plt.yticks(power)
plt.xlabel('MSE')
plt.ylabel('Power')
plt.title('Train')
# Out:
# Text(0.5,1,'Train')

# %%
plt.plot(MSET,power,'r*')
plt.yticks(power)
plt.xlabel('MSE')
plt.ylabel('Power')
plt.title('Test')
# Out:
# Text(0.5,1,'Test')

# %%
train_sizes, train_score, test_score = learning_curve(model, X, Y, cv=5)

# %%
plt.plot(train_sizes, test_score.mean(axis=1), 'bo-', label='test')
plt.plot(train_sizes, train_score.mean(axis=1), 'go-', label='train')
plt.legend()
plt.grid()
